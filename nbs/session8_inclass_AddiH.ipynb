# %% [markdown]
# # Introducing CNNS with TensorFlow
#
#
# In this notebook, we're going to see how we can use ```TensorFlow``` to build convolutional neural networks to work with colour image data.

# %% [markdown]
# ## Load libraries

# %%
# data tools
import os
import numpy as np
import matplotlib.pyplot as plt

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# tf tools
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
# Out:
# 2023-03-31 13:18:58.009115: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-31 13:18:58.055986: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-31 13:18:58.059389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 13:18:58.842785: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# __Define plotting function__

# %%
def plot_history(H, epochs):
    plt.style.use("seaborn-colorblind")

    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss", linestyle=":")
    plt.title("Loss curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc", linestyle=":")
    plt.title("Accuracy curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# __Load cifar10 data__

# %% [markdown]
# We first want to load the ```cifar-10``` dataset, normalize the values, and then binarize the labels.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 7s 0us/step

# %% [markdown]
# **Question:** As an experiment, see what happens if you try to train the model with un-scaled images. Does it affect performance?

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# create one-hot encodings
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %% [markdown]
# We'll also manually create a list of labels for when we come to print the classification report later.

# %%
# initialize label names for CIFAR-10 dataset
label_names = ["airplane", "automobile", 
              "bird", "cat", 
              "deer", "dog", 
              "frog", "horse", 
              "ship", "truck"]

# %% [markdown]
# ## ShallowNet

# %% [markdown]
# We're going to begin by creating one of the simplest CNN architectures with only a single convolutional layer. This type of architecture is known as the ShallowNet architecture:
# >INPUT => CONV => ReLU => FC

# %%
#initalise model
model = Sequential()

# define CONV => ReLU
model.add(Conv2D(32, # convolutional 32x32
                (3,3), # kernel size
                padding = "same", # copy the pic instead of 0 padding
                input_shape = (32, 32, 3))) # takes 32x32 3 color pictures
model.add(Activation("relu"))
          
# FC classifier
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %% [markdown]
# We then compile our model using some of the same arguments we've already seen in different contexts.

# %%
sgd = SGD(learning_rate =.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_3 (Activation)   (None, 32, 32, 32)        0
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_2 (Dense)             (None, 128)               4194432
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 4,196,618
# Trainable params: 4,196,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Plot model__

# %%
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# __Train model__

# %% [markdown]
# Finally, we train the model on the data and get our predictions.

# %%
H = model.fit(X_train, 
              y_train,
              validation_split=0.1,
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 11s 7ms/step - loss: 2.0479 - accuracy: 0.2816 - val_loss: 1.9193 - val_accuracy: 0.3252
# Epoch 2/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.8385 - accuracy: 0.3588 - val_loss: 1.8329 - val_accuracy: 0.3666
# Epoch 3/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7661 - accuracy: 0.3855 - val_loss: 1.7610 - val_accuracy: 0.3832
# Epoch 4/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7143 - accuracy: 0.4042 - val_loss: 1.7259 - val_accuracy: 0.3920
# Epoch 5/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6714 - accuracy: 0.4198 - val_loss: 1.7089 - val_accuracy: 0.4010
# Epoch 6/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6328 - accuracy: 0.4321 - val_loss: 1.6559 - val_accuracy: 0.4224
# Epoch 7/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5992 - accuracy: 0.4434 - val_loss: 1.6101 - val_accuracy: 0.4310
# Epoch 8/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5673 - accuracy: 0.4561 - val_loss: 1.6092 - val_accuracy: 0.4206
# Epoch 9/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5399 - accuracy: 0.4629 - val_loss: 1.5611 - val_accuracy: 0.4510
# Epoch 10/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5156 - accuracy: 0.4723 - val_loss: 1.5290 - val_accuracy: 0.4638
# Epoch 11/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4913 - accuracy: 0.4818 - val_loss: 1.5346 - val_accuracy: 0.4672
# Epoch 12/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4689 - accuracy: 0.4871 - val_loss: 1.4989 - val_accuracy: 0.4744
# Epoch 13/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4458 - accuracy: 0.4960 - val_loss: 1.4921 - val_accuracy: 0.4702
# Epoch 14/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4241 - accuracy: 0.5033 - val_loss: 1.4611 - val_accuracy: 0.4830
# Epoch 15/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4046 - accuracy: 0.5075 - val_loss: 1.4483 - val_accuracy: 0.4900
# Epoch 16/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3830 - accuracy: 0.5182 - val_loss: 1.4220 - val_accuracy: 0.4926
# Epoch 17/20
# 1407/1407 [==============================] - 11s 7ms/step - loss: 1.3644 - accuracy: 0.5233 - val_loss: 1.4028 - val_accuracy: 0.5052
# Epoch 18/20
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.3453 - accuracy: 0.5317 - val_loss: 1.3948 - val_accuracy: 0.5066
# Epoch 19/20
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.3268 - accuracy: 0.5371 - val_loss: 1.3870 - val_accuracy: 0.5046
# Epoch 20/20
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.3096 - accuracy: 0.5428 - val_loss: 1.3498 - val_accuracy: 0.5172

# %% [markdown]
# __Evaluate model__

# %%
predictions = model.predict(X_test, batch_size=32)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.56      0.63      0.60      1000
#   automobile       0.59      0.69      0.64      1000
#         bird       0.46      0.31      0.37      1000
#          cat       0.39      0.33      0.36      1000
#         deer       0.47      0.41      0.44      1000
#          dog       0.40      0.45      0.42      1000
#         frog       0.47      0.72      0.57      1000
#        horse       0.63      0.52      0.57      1000
#         ship       0.72      0.54      0.61      1000
#        truck       0.57      0.62      0.59      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.53      0.52      0.52     10000
# weighted avg       0.53      0.52      0.52     10000

# %% [markdown]
# We can also use the ```plot_history()``` function available from ```TensorFlow``` to see how our model performs during training.
#
# These plots can tell us *a lot* about whether a model is under- or over-fiting the data. You read more at [this fantastic blog post](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Other useful blogs are [here](https://rstudio-conf-2020.github.io/dl-keras-tf/notebooks/learning-curve-diagnostics.nb.html) and there's a good video overview [here](https://youtu.be/p3CcfIjycBA).

# %%
plot_history(H, 20)
# Out:
# /tmp/ipykernel_1147/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %% [markdown]
# ## LeNet

# %% [markdown]
# Next, we'll look at a slightly more complicated CNN architecture, known as ```LeNet``` after its creator Yann LeCun, who is now Chief AI Scientist at Meta. You can read more [here](https://en.wikipedia.org/wiki/LeNet).
# >INPUT => CONV => ReLU => MAXPOOL => CONV => ReLU => MAXPOOL => FC => ReLU => FC

# %% [markdown]
# __Define model__

# %%
# define model
model = Sequential()

# first set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(32, (3,3),
                 padding="same",
                 input_shape=(32,32,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# second set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(50, (5,5),
                 padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# FC => RELU
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

# softmax classifier
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %%
sgd = SGD(learning_rate=0.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_6 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 50)        40050
#
#  activation_7 (Activation)   (None, 16, 16, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 50)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3200)              0
#
#  dense_4 (Dense)             (None, 128)               409728
#
#  activation_8 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
#  activation_9 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 451,964
# Trainable params: 451,964
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %%
# train model
H = model.fit(X_train, 
              y_train, 
              validation_split=0.1, 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 2.2650 - accuracy: 0.1639 - val_loss: 2.2090 - val_accuracy: 0.2162
# Epoch 2/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 2.1087 - accuracy: 0.2523 - val_loss: 2.0169 - val_accuracy: 0.2924
# Epoch 3/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.9606 - accuracy: 0.3060 - val_loss: 1.9376 - val_accuracy: 0.3192
# Epoch 4/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.8877 - accuracy: 0.3348 - val_loss: 1.8658 - val_accuracy: 0.3382
# Epoch 5/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.8235 - accuracy: 0.3628 - val_loss: 1.8062 - val_accuracy: 0.3548
# Epoch 6/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.7602 - accuracy: 0.3844 - val_loss: 1.7526 - val_accuracy: 0.3794
# Epoch 7/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.7006 - accuracy: 0.4042 - val_loss: 1.6744 - val_accuracy: 0.4036
# Epoch 8/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.6440 - accuracy: 0.4237 - val_loss: 1.6691 - val_accuracy: 0.4088
# Epoch 9/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.5910 - accuracy: 0.4406 - val_loss: 1.5946 - val_accuracy: 0.4216
# Epoch 10/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.5469 - accuracy: 0.4539 - val_loss: 1.5737 - val_accuracy: 0.4282
# Epoch 11/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.5059 - accuracy: 0.4655 - val_loss: 1.5248 - val_accuracy: 0.4514
# Epoch 12/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.4707 - accuracy: 0.4786 - val_loss: 1.4906 - val_accuracy: 0.4672
# Epoch 13/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.4448 - accuracy: 0.4885 - val_loss: 1.4445 - val_accuracy: 0.4826
# Epoch 14/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.4198 - accuracy: 0.4991 - val_loss: 1.4460 - val_accuracy: 0.4860
# Epoch 15/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3992 - accuracy: 0.5074 - val_loss: 1.4122 - val_accuracy: 0.5002
# Epoch 16/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3799 - accuracy: 0.5120 - val_loss: 1.3785 - val_accuracy: 0.5072
# Epoch 17/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.3621 - accuracy: 0.5193 - val_loss: 1.3647 - val_accuracy: 0.5166
# Epoch 18/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 1.3468 - accuracy: 0.5260 - val_loss: 1.3444 - val_accuracy: 0.5230
# Epoch 19/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3294 - accuracy: 0.5304 - val_loss: 1.3489 - val_accuracy: 0.5250
# Epoch 20/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3158 - accuracy: 0.5351 - val_loss: 1.4289 - val_accuracy: 0.4858

# %%
plot_history(H,20)
# Out:
# /tmp/ipykernel_1147/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %%
predictions = model.predict(X_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
# 313/313 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.60      0.55      0.58      1000
#   automobile       0.66      0.64      0.65      1000
#         bird       0.48      0.28      0.36      1000
#          cat       0.26      0.67      0.37      1000
#         deer       0.56      0.29      0.38      1000
#          dog       0.51      0.29      0.37      1000
#         frog       0.52      0.67      0.58      1000
#        horse       0.54      0.61      0.57      1000
#         ship       0.84      0.33      0.47      1000
#        truck       0.55      0.60      0.57      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.55      0.49      0.49     10000
# weighted avg       0.55      0.49      0.49     10000
